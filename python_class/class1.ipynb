# %%
user_feelings = ['angry','angry','neutral','happy','neutral','excited','happy','neutral','happy','happy']
group = ['angry','excited','happy','neutral']

result = set(user_feelings)
print(result)
# Out:
# {'neutral', 'excited', 'happy', 'angry'}
